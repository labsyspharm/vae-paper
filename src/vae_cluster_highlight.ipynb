# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
clustering = 'VAE9'

# %%
# Paths and input
out = os.path.join(os.getcwd(), f'output/cluster_hightlight_{clustering}')
if not os.path.exists(out):
    os.makedirs(out)

# Read single-cell sample for VAE analysis
main = pd.read_csv(os.path.join(os.getcwd(), 'input/main.csv'))

# %%
for i in sorted(main[clustering].unique()):
    if i != -1:
        print(f'{clustering} cluster {i}')
        plt.scatter(main[f'{clustering}_emb1'], main[f'{clustering}_emb2'], lw=0.0, s=0.01, c='gainsboro')
        plt.scatter(
            main[f'{clustering}_emb1'][main[clustering] == i],
            main[f'{clustering}_emb2'][main[clustering] == i],
            s=0.01, lw=0.0, c='tab:red'
        )
        plt.savefig(os.path.join(out, f'{clustering}_{i}.png'), dpi=800, bbox_inches='tight')
        plt.show()
        plt.close('all')
# Out:
# VAE9 cluster 0
# VAE9 cluster 1
# VAE9 cluster 2
# VAE9 cluster 3
# VAE9 cluster 4
# VAE9 cluster 5
# VAE9 cluster 6
# VAE9 cluster 7
# VAE9 cluster 8
# VAE9 cluster 9
# VAE9 cluster 10
# VAE9 cluster 11
# VAE9 cluster 12
# VAE9 cluster 13
# VAE9 cluster 14
# VAE9 cluster 15
# VAE9 cluster 16
# VAE9 cluster 17
# VAE9 cluster 18
# VAE9 cluster 19
# VAE9 cluster 20
# VAE9 cluster 21
# VAE9 cluster 22
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/venvs/vae/lib/python3.9/site-packages/PIL/ImageFile.py:515, in _save(im, fp, tile, bufsize)
#     514 try:
# --> 515     fh = fp.fileno()
#     516     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
# ...
