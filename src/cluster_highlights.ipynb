# %%
import os

import pandas as pd
import matplotlib.pyplot as plt

# %%
# I/O
main = pd.read_csv(os.path.join(os.getcwd(), '../input/main.csv'))

out = os.path.join(os.getcwd(), '../output/cluster_highlights')
if not os.path.exists(out):
    os.makedirs(out)

# %%
# plot
for clustering, emb in zip(['Seg', 'VAE9_VIG7', 'VAE30'], ['Seg_emb', 'VAE9_VIG7_emb', 'VAE30_emb']): 

    data = main.sample(frac=0.05)
    
    for i in sorted(data[clustering].unique()):
        if i != -1:
            
            print(f'{clustering} cluster {i}')
            
            fig = plt.figure()
            ax = plt.axes(projection='3d', computed_zorder=False)
            
            if clustering == 'Seg':
                ax.view_init(elev=10, azim=230)
            elif clustering == 'VAE9_VIG7':
                ax.view_init(elev=10, azim=236)
            elif clustering == 'VAE30':
                ax.view_init(elev=10, azim=240)

            ax.scatter(
                data[f'{emb}1'],
                data[f'{emb}2'],
                data[f'{emb}3'],
                c='gainsboro', linewidth=0.0, s=2, alpha=0.5
            )
            ax.scatter(
                data[f'{emb}1'][data[clustering] == i],
                data[f'{emb}2'][data[clustering] == i],
                data[f'{emb}3'][data[clustering] == i],
                color=(0, 0.33, 1), linewidth=0.0, s=3, alpha=1,
            )
            ax.set_xlabel('UMAP1')
            ax.set_ylabel('UMAP2')
            ax.set_zlabel('UMAP3')

            ax.axis('auto')
            ax.tick_params(labelsize=10)
            ax.grid(True)
            plt.tight_layout()
            
            plt.savefig(os.path.join(out, f'{clustering}_cluster_{i}.png'), dpi=800)
            
            plt.show()
# Out:
# Seg cluster 0
# Seg cluster 1
# Seg cluster 2
# Seg cluster 3
# Seg cluster 4
# Seg cluster 5
# Seg cluster 6
# Seg cluster 7
# Seg cluster 8
# Seg cluster 9
# Seg cluster 10
# Seg cluster 11
# Seg cluster 12
# Seg cluster 13
# Seg cluster 14
# Seg cluster 15
# Seg cluster 16
# Seg cluster 17
# VAE9_VIG7 cluster 0
# VAE9_VIG7 cluster 1
# VAE9_VIG7 cluster 2
# VAE9_VIG7 cluster 3
# VAE9_VIG7 cluster 4
# VAE9_VIG7 cluster 5
# VAE9_VIG7 cluster 6
# VAE9_VIG7 cluster 7
# VAE9_VIG7 cluster 8
# VAE9_VIG7 cluster 9
# VAE9_VIG7 cluster 10
# VAE9_VIG7 cluster 11
# VAE9_VIG7 cluster 12
# VAE9_VIG7 cluster 13
# VAE9_VIG7 cluster 14
# VAE9_VIG7 cluster 15
# VAE9_VIG7 cluster 16
# VAE9_VIG7 cluster 17
# VAE9_VIG7 cluster 18
# VAE9_VIG7 cluster 19
# VAE9_VIG7 cluster 20
# VAE9_VIG7 cluster 21
# VAE9_VIG7 cluster 22
# VAE9_VIG7 cluster 23
# VAE30 cluster 0
# VAE30 cluster 1
# VAE30 cluster 2
# VAE30 cluster 3
# VAE30 cluster 4
# VAE30 cluster 5
# VAE30 cluster 6
# VAE30 cluster 7
# VAE30 cluster 8
# ...
