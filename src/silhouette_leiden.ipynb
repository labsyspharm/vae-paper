# %%
import os

import numpy as np
import pandas as pd

import math

from matplotlib import colors
import matplotlib.pyplot as plt

from sklearn.metrics import silhouette_samples, silhouette_score

from utils.utility_functions import categorical_cmap

# %%
out = os.path.join(os.getcwd(), 'output/silhouette_leiden')
if not os.path.exists(out):
    os.makedirs(out)

data = pd.read_parquet(
    os.path.join(os.getcwd(), 'input/CRC-097_clean_cylinter_clustering_3d_leiden.parquet')
)
silho_input = data[['emb1', 'emb2', 'emb3', 'cluster_2d']]

# Subsample clustered data for silhouette analysis
silho_subset = silho_input.sample(n=50000, random_state=1)

cmap = categorical_cmap(
    numUniqueSamples=len(silho_input['cluster_2d'].unique()),
    numCatagories=10, cmap='tab10', continuous=False
)

cluster_centers = pd.DataFrame(
    index=sorted(silho_subset['cluster_2d'].unique())
)

embed_cols = [i for i in silho_subset.columns if 'emb' in i]
for clus in sorted(silho_subset['cluster_2d'].unique()):
    group = silho_subset[silho_subset['cluster_2d'] == clus]
    for emb_dim in embed_cols:
        emb_mean = group[emb_dim].mean()
        cluster_centers.loc[clus, emb_dim] = emb_mean

n_clusters = len(cluster_centers.index.unique())

silhouette_spacer = 1000

# %%
# Plot
fig_silho = plt.figure(figsize=(18, 7))
gs = plt.GridSpec(1, 2, figure=fig_silho)
ax1_silho = fig_silho.add_subplot(gs[0, 0], projection=None)
ax2_silho = fig_silho.add_subplot(gs[0, 1], projection='3d')

ax1_silho.set_xlim([-1, 1])

ax1_silho.set_ylim([0, len(silho_subset) + (n_clusters + 1) * silhouette_spacer])

sample_silhouette_values = silhouette_samples(silho_subset[embed_cols], silho_subset['cluster_2d'])

y_lower = silhouette_spacer

neg = {}
for i in cluster_centers.index.unique():

    ith_cluster_silhouette_values = (sample_silhouette_values[silho_subset['cluster_2d'] == i])
    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]

    frac_neg = (np.sum(ith_cluster_silhouette_values < 0)/size_cluster_i)*100
    print(f'Fraction of cells with negative silhouette scores for cluster {i}: {frac_neg}')
    neg[i] = frac_neg
    
    y_upper = y_lower + size_cluster_i

    color = cmap.colors[i]

    ax1_silho.fill_betweenx(
        np.arange(y_lower, y_upper), 0, ith_cluster_silhouette_values,
        facecolor=color, edgecolor=color, alpha=0.7
    )

    ax1_silho.text(
        0.0, y_lower + 0.5 * size_cluster_i, str(i),
        fontdict={'size': 20 / np.log(n_clusters)}
    )

    # compute the new y_lower for next plot
    y_lower = y_upper + silhouette_spacer

print(f'Standard deviation for fraction of cells with negative silhouette scores is: {np.std(list(neg.values()))}')

silhouette_avg = silhouette_score(silho_subset[embed_cols], silho_subset['cluster_2d'])

ax1_silho.set_title('Silhouette Plot')
ax1_silho.set_xlabel('Silhouette Coefficients')
ax1_silho.set_ylabel('Cluster label')

ax1_silho.axvline(x=silhouette_avg, color='r', lw=0.75, linestyle='--')

ax1_silho.set_yticks([])

ax2_silho.scatter(
    silho_subset['emb1'], silho_subset['emb2'], silho_subset['emb3'],
    marker='.', s=30, edgecolor='k', lw=0, alpha=1.0,
    c=[cmap.colors[i] for i in silho_subset['cluster_2d']]
)

ax2_silho.scatter(
    cluster_centers['emb1'], cluster_centers['emb2'], cluster_centers['emb3'],
    marker='o', c='white', alpha=1, s=125, edgecolor='k'
)

for i in cluster_centers.iterrows():
    ax2_silho.scatter(
        i[1]['emb1'], i[1]['emb2'], i[1]['emb3'],
        marker='$%d$' % i[0], zorder=100, alpha=1, s=40,
        edgecolor='k'
    )

ax2_silho.set_title('Clustering')
ax2_silho.set_xlabel('Feature Space 1')
ax2_silho.set_ylabel('Feature Space 2')

total_clusters = len(silho_input['cluster_2d'].unique())

fig_silho.suptitle('Leiden', fontsize=14, fontweight='bold')

plt.savefig(os.path.join(out, 'silhouette_leiden.pdf'), bbox_inches='tight')
plt.show()
plt.close('all')
# Out:
# Fraction of cells with negative silhouette scores for cluster 0: 8.226095455285877
# Fraction of cells with negative silhouette scores for cluster 1: 37.67337807606264
# Fraction of cells with negative silhouette scores for cluster 2: 36.25160462130937
# Fraction of cells with negative silhouette scores for cluster 3: 34.59827270348077
# Fraction of cells with negative silhouette scores for cluster 4: 3.0070754716981134
# Fraction of cells with negative silhouette scores for cluster 5: 13.152866242038217
# Fraction of cells with negative silhouette scores for cluster 6: 28.66303302340494
# Fraction of cells with negative silhouette scores for cluster 7: 3.0660377358490565
# Fraction of cells with negative silhouette scores for cluster 8: 16.22641509433962
# Fraction of cells with negative silhouette scores for cluster 9: 11.782477341389729
# Fraction of cells with negative silhouette scores for cluster 10: 9.94263862332696
# Fraction of cells with negative silhouette scores for cluster 11: 9.052388289676424
# Fraction of cells with negative silhouette scores for cluster 12: 7.2710103871576965
# Fraction of cells with negative silhouette scores for cluster 13: 32.354357246027924
# Fraction of cells with negative silhouette scores for cluster 14: 6.475349521707138
# Fraction of cells with negative silhouette scores for cluster 15: 13.169073916737467
# Fraction of cells with negative silhouette scores for cluster 16: 13.876040703052727
# Fraction of cells with negative silhouette scores for cluster 17: 5.7591623036649215
# Fraction of cells with negative silhouette scores for cluster 18: 25.0
# Standard deviation for fraction of cells with negative silhouette scores is: 11.515013866215657
